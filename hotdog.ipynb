# %% [markdown]
# <a href="https://colab.research.google.com/github/ettyang/DS-4002/blob/spring-2025_section-18751/hotdog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/hot_dog_survey_spring25.xlsx - Form Responses 1.csv')
df.head()
# Out:
#             Timestamp  \
# 0  1/15/2025 21:53:05
# 1  1/15/2025 21:53:51
# 2  1/15/2025 21:54:43
# 3  1/15/2025 21:56:43
# 4  1/15/2025 21:57:59
#
#   Do you believe that a hotdog falls under the category of a sandwich?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                              Yesss
# 4                                                 NO
#
#           What is the rationale behind your opinion?  \
# 0  The content inside isn’t covered u can see the...
# 1  Sandwich bread is two separate slices, hotdog ...
# 2                             the bread is connected
# 3  It is a piece of meat encapsulated by bread! I...
# 4  A hot dog is not a sandwich because its openin...
#
#   Are you currently enrolled as an undergraduate or graduate student at the University of Virginia?  \
# 0                                                Yes
# ...

# %%
# getting data we care about
responses = df[['Do you believe that a hotdog falls under the category of a sandwich?', 'What state or country were you born in?', 'Are you currently enrolled as an undergraduate or graduate student at the University of Virginia?']]

# %%
# throwing out non UVA people
uva = []
for k in range(len(responses['Are you currently enrolled as an undergraduate or graduate student at the University of Virginia?'])):
  if any(s.lower() == "y" for s in k):
    uva.append(k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-acc756a30aa8> in <cell line: 0>()
#       2 uva = []
#       3 for k in range(len(responses['Are you currently enrolled as an undergraduate or graduate student at the University of Virginia?'])):
# ----> 4   if any(s.lower() == "y" for s in k):
#       5     uva.append(k)
#
# TypeError: 'int' object is not iterable

# %%
def clean_yes_no(answer):

    answer = str(answer).lower()
    if 'y' in answer:
        return "Yes"
    elif 'n' in answer:
        return "No"
    else:
        return "Unknown"

# Apply the cleaning function to the relevant column
uva_response['Are you currently enrolled as an undergraduate or graduate at the University of Virginia?'] = uva_responses['Are you currently enrolled as an undergraduate or graduate at the University of Virginia?'].apply(clean_yes_no)

# Show the cleaned data
print(uva_responses)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-59f6db1027e9> in <cell line: 0>()
#      10
#      11 # Apply the cleaning function to the relevant column
# ---> 12 uva_response['Are you currently enrolled as an undergraduate or graduate at the University of Virginia?'] = uva_responses['Are you currently enrolled as an undergraduate or graduate at the University of Virginia?'].apply(clean_yes_no)
#      13
#      14 # Show the cleaned data
#
# NameError: name 'uva_responses' is not defined
